# %%
import pandas as pd

data=pd.read_csv("d2.csv")
print("Dataset is:\n")
print(data)
# Out:
# Dataset is:
#
#      b  30.83       0  u  g   w   v  1.25  t t.1  1  f g.1  202  0.1  +
# 0    a  58.67   4.460  u  g   q   h  3.04  t   t  6  f   g   43  560  +
# 1    a   24.5   0.500  u  g   q   h  1.50  t   f  0  f   g  280  824  +
# 2    b  27.83   1.540  u  g   w   v  3.75  t   t  5  t   g  100    3  +
# 3    b  20.17   5.625  u  g   w   v  1.71  t   f  0  f   g  120    0  +
# 4    b  32.08   4.000  u  g   m   v  2.50  t   f  0  t   g  360    0  +
# ..  ..    ...     ... .. ..  ..  ..   ... ..  .. .. ..  ..  ...  ... ..
# 684  b  21.08  10.085  y  p   e   h  1.25  f   f  0  f   g  260    0  -
# 685  a  22.67   0.750  u  g   c   v  2.00  f   t  2  t   g  200  394  -
# 686  a  25.25  13.500  y  p  ff  ff  2.00  f   t  1  t   g  200    1  -
# 687  b  17.92   0.205  u  g  aa   v  0.04  f   f  0  f   g  280  750  -
# 688  b     35   3.375  u  g   c   h  8.29  f   f  0  t   g    0    0  -
#
# [689 rows x 16 columns]

# %%
import numpy as np

att=np.array(data)[:,:-1]
print("The attributes in the datset are: \n",att)
# Out:
# The attributes in the datset are:
#  [['a' '58.67' 4.46 ... 'g' '43' 560]
#  ['a' '24.5' 0.5 ... 'g' '280' 824]
#  ['b' '27.83' 1.54 ... 'g' '100' 3]
#  ...
#  ['a' '25.25' 13.5 ... 'g' '200' 1]
#  ['b' '17.92' 0.205 ... 'g' '280' 750]
#  ['b' '35' 3.375 ... 'g' '0' 0]]

# %%
trgt=np.array(data)[:,-1]
print("The target is: \n",trgt)
# Out:
# The target is:
#  ['+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '+'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '-' '-' '-' '-' '-' '+' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-']

# %%
def train(c,t):
    for i,out in enumerate(t):
        if out=="+":
            s_hyp=c[i].copy()
            break
             
    for i,out in enumerate(c):
        if t[i]=="+":
            for x in range(len(s_hyp)):
                if out[x]!=s_hyp[x]:
                    s_hyp[x]='?'
                else:
                    pass
                 
    return s_hyp

# %%
print("The final specific hypothesis is:",train(att,trgt))
# Out:
# The final specific hypothesis is: ['?' '?' '?' '?' '?' '?' '?' '?' '?' '?' '?' '?' 'g' '?' '?']

# %%
import pandas as pd
import numpy as np

data=pd.read_csv("d2.csv")
print("Dataset is:\n")
print(data)

att=np.array(data)[:,:-1]
print("\nThe attributes in the datset are: \n",att)

trgt=np.array(data)[:,-1]
print("\nThe target is: \n",trgt)

def train(c,t):
    for i,out in enumerate(t):
        if out=="+":
            s_hyp=c[i].copy()
            break
             
    for i,out in enumerate(c):
        if t[i]=="+":
            for x in range(len(s_hyp)):
                if out[x]!=s_hyp[x]:
                    s_hyp[x]='?'
                else:
                    pass
                 
    return s_hyp

print("\n\nThe final specific hypothesis is:",train(att,trgt))
# Out:
# Dataset is:
#
#      b  30.83       0  u  g   w   v  1.25  t t.1  1  f g.1  202  0.1  +
# 0    a  58.67   4.460  u  g   q   h  3.04  t   t  6  f   g   43  560  +
# 1    a   24.5   0.500  u  g   q   h  1.50  t   f  0  f   g  280  824  +
# 2    b  27.83   1.540  u  g   w   v  3.75  t   t  5  t   g  100    3  +
# 3    b  20.17   5.625  u  g   w   v  1.71  t   f  0  f   g  120    0  +
# 4    b  32.08   4.000  u  g   m   v  2.50  t   f  0  t   g  360    0  +
# ..  ..    ...     ... .. ..  ..  ..   ... ..  .. .. ..  ..  ...  ... ..
# 684  b  21.08  10.085  y  p   e   h  1.25  f   f  0  f   g  260    0  -
# 685  a  22.67   0.750  u  g   c   v  2.00  f   t  2  t   g  200  394  -
# 686  a  25.25  13.500  y  p  ff  ff  2.00  f   t  1  t   g  200    1  -
# 687  b  17.92   0.205  u  g  aa   v  0.04  f   f  0  f   g  280  750  -
# 688  b     35   3.375  u  g   c   h  8.29  f   f  0  t   g    0    0  -
#
# [689 rows x 16 columns]
#
# The attributes in the datset are:
#  [['a' '58.67' 4.46 ... 'g' '43' 560]
#  ['a' '24.5' 0.5 ... 'g' '280' 824]
#  ['b' '27.83' 1.54 ... 'g' '100' 3]
#  ...
#  ['a' '25.25' 13.5 ... 'g' '200' 1]
#  ['b' '17.92' 0.205 ... 'g' '280' 750]
#  ['b' '35' 3.375 ... 'g' '0' 0]]
#
# The target is:
#  ['+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '+'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+' '+'
#  '+' '+' '+' '+' '+' '+' '-' '-' '-' '-' '-' '+' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '+' '+' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-'
#  '-' '-' '-' '-' '-']
#
#
# The final specific hypothesis is: ['?' '?' '?' '?' '?' '?' '?' '?' '?' '?' '?' '?' 'g' '?' '?']
